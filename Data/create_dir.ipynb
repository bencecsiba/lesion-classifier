# %%
import os
import random
import pandas as pd

# %%
_ = []

for i in ['HAM10000_images_part_1', 'HAM10000_images_part_2']:
    for j in os.listdir(i):
        num = random.randint(1, 10)
        path_start = '/Users/bence/Documents/Personal Projects/Skin/Data/'

        if num > 8:
            os.replace(path_start + i + '/' + j, path_start + 'test' + '/' + j)
        else:
            os.replace(path_start + i + '/' + j, path_start + 'train' + '/' + j)

# %%
metadata = pd.read_csv('HAM10000_metadata.csv')

# %%
metadata.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
dxs = set(metadata['dx'])

for i in dxs:
    for j in ['test', 'train']:
        os.mkdir('/Users/bence/Documents/Personal Projects/Skin/Data/Images/' + j + '/' + i)

# %%
metadata.loc[metadata['image_id'] == 'ISIC_0027419']['dx'][0]
# Out:
# 'bkl'

# %%
image_dir = '/Users/bence/Documents/Personal Projects/Skin/Data/Images/'

for i in ['test', 'train']:
    for j in os.listdir(image_dir + i):
        image_name = j[:-4]
        print(metadata[metadata['image_id'] == image_name]['dx'])
        if len(metadata[metadata['image_id'] == image_name]['dx'])> 0:
            dx = metadata[metadata['image_id'] == image_name]['dx'].iloc[0]
            os.replace(image_dir + i + '/' + j, image_dir + i + '/' + dx + '/' + j)
# Out:
# Series([], Name: dx, dtype: object)
# 2025    mel
# Name: dx, dtype: object
# 6449    nv
# Name: dx, dtype: object
# 8439    nv
# Name: dx, dtype: object
# 5825    nv
# Name: dx, dtype: object
# 7506    nv
# Name: dx, dtype: object
# 7736    nv
# Name: dx, dtype: object
# 6886    nv
# Name: dx, dtype: object
# 2133    mel
# Name: dx, dtype: object
# 1062    bkl
# Name: dx, dtype: object
# 4537    nv
# Name: dx, dtype: object
# 3714    nv
# Name: dx, dtype: object
# 645    bkl
# Name: dx, dtype: object
# 2183    mel
# Name: dx, dtype: object
# 7061    nv
# Name: dx, dtype: object
# 7332    nv
# Name: dx, dtype: object
# 8813    nv
# Name: dx, dtype: object
# 1940    mel
# Name: dx, dtype: object
# 4740    nv
# Name: dx, dtype: object
# 6971    nv
# Name: dx, dtype: object
# 6203    nv
# Name: dx, dtype: object
# 2058    mel
# Name: dx, dtype: object
# 3624    nv
# Name: dx, dtype: object
# 495    bkl
# Name: dx, dtype: object
# 9082    nv
# Name: dx, dtype: object
# 7711    nv
# ...
